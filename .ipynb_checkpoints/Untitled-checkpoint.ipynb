# %% [markdown]
# **PROYECTO FINAL**

# %%
import os

# %% [markdown]
# 1. Localizando directorio

# %%
directorio_actual = os.getcwd()
idh_nombre = 'IDH_PNUD_2017'
ruta_completa = os.path.join (directorio_actual, idh_nombre)

print (ruta_completa)
# Out:
# C:\Users\ivann\OneDrive\Documentos\QLAB - verano 2024-0\PYTHON\Proyecto_final2024\IDH_PNUD_2017

# %% [markdown]
# 2. Importando data

# %%
import pandas as pd

# %%
locacion_datos = r"C:\Users\ivann\OneDrive\Documentos\QLAB - verano 2024-0\PYTHON\Proyecto_final2024\IDH_PNUD_2017.xlsx"

if os.path.exists(locacion_datos):
    idh = pd.read_excel(locacion_datos)
    print(idh.head())
else:
    print(f"El archivo no existe en la ruta especificada: {locacion_datos}")
# Out:
#   Índice de Desarollo Humano IDH 2017    Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                 NaN           NaN        NaN         NaN
# 1                              UBIGEO  DEPARTAMENTO        NaN         NaN
# 2                                 NaN           NaN  Provincia         NaN
# 3                                 NaN           NaN   Distrito         NaN
# 4                                 NaN           NaN        NaN         NaN
#
#    Unnamed: 4       Unnamed: 5                  Unnamed: 6  \
# 0         NaN              NaN                         NaN
# 1         NaN  Población total  Esperanza de vida al nacer
# 2         NaN              NaN                         NaN
# 3         NaN       habitantes                        Años
# 4         NaN              NaN                         NaN
#
#                                           Unnamed: 7  \
# 0                                    Logro educativo
# ...

# %%
idh
# Out:
#                     Índice de Desarollo Humano IDH 2017    Unnamed: 1  \
# 0                                                   NaN           NaN
# 1                                                UBIGEO  DEPARTAMENTO
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 2299                                             250401             1
# 2300                                                NaN           NaN
# 2301  Fuente: INEI. Censo de Población y Vivienda 20...           NaN
# 2302  Elaboración: PNUD / Unidad del Informe sobre D...           NaN
# 2303                    1/ Provincias de Lima y Callao.           NaN
#
#      Unnamed: 2  Unnamed: 3  Unnamed: 4       Unnamed: 5  \
# 0           NaN         NaN         NaN              NaN
# ...

# %% [markdown]
# 3. Limpieza de datos

# %% [markdown]
# 3.1 Elimnando filas

# %%
# Eliminar la fila con índice 1
idh = idh_.drop(1)

# Mostrar el DataFrame resultante
print(idh_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Eliminar la fila con índice 1
# ----> 2 idh = idh_.drop(1)
#       4 # Mostrar el DataFrame resultante
#       5 print(idh_)
#
# NameError: name 'idh_' is not defined
